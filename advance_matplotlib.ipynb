# %%
from mpl_toolkits import mplot3d 
import numpy as np 
import matplotlib.pyplot as plt 
  
  
# Creating dataset 
z = np.random.randint(100, size =(50)) 
x = np.random.randint(80, size =(50)) 
y = np.random.randint(60, size =(50)) 
colors=np.random.randint(1,3,size=len(x))
# Creating figure 
fig = plt.figure(figsize = (10, 7)) 
ax = plt.axes(projection ="3d") 
  
# Creating plot  
ax.scatter3D(x, y, z, c =colors)

plt.title("simple 3D scatter plot") 
  
# show plot 
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import numpy as np
x=np.arange(0,10,0.1)
y=np.random.rand(len(x))
z=np.random.rand(len(y))
fig=plt.figure(figsize = (10, 7))
ax=plt.axes()
ax.scatter(x,y,z, c='blue')
plt.show()

# %%
from pylab import *
import numpy as np
x=arange(0,10,0.1)
y=randn(len(x))
plot(x,y)
title('plot with pylab')
show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from sklearn import datasets
from sklearn.decomposition import PCA
iris=datasets.load_iris()
species=iris.target
x_reduced=PCA(n_components=3).fit_transform(iris.data)
fig=plt.Figure()
#ax=axes3d(fig)
ax.scatter(x_reduced[:,0],x_reduced[:,1],x_reduced[:,3],c=species)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-413d15f0f38d> in <module>
#       7 x_reduced=PCA(n_components=3).fit_transform(iris.data)
#       8 fig=plt.Figure()
# ----> 9 ax=axes3d(fig)
#      10 ax.scatter(x_reduced[:,0],x_reduced[:,1],x_reduced[:,3],c=species)
#      11 plt.show()
#
# TypeError: 'module' object is not callable

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,10,0.1)
y=np.random.rand(len(x))
fig=plt.figure()
ax=fig.add_subplot(111)
l,=plt.plot(x,y)
l.set_color('red')
ax.set_title('plot with oo')
plt.show()

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_subplot(212)
ax.plot([1,2,3],[1,2,3])
ax1=fig.add_subplot(212)
ax1.plot([1,2,3],[3,2,1])
ax2=fig.add_subplot(222)
ax2.plot([1,2,3],[4,3,5])
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_subplot(211)
ax.plot([1,2,3],[1,2,3],color='b')
ax1=fig.add_subplot(212)
ax1.plot([1,2,3],[3,2,1],color='r')
ax2=fig.add_subplot(221)
ax2.plot([1,2,3],[4,3,5],color='g')
plt.show()
